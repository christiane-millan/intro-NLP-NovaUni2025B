# %% [markdown]
# # Predicción de Calificaciones de Recomendación de Productos de Comercio Electrónico a partir de Reseñas
#
# Este es un problema clásico de procesamiento de lenguaje natural (NLP) que trabaja con datos de una tienda de comercio electrónico enfocada en ropa para mujeres. Cada registro en el conjunto de datos es una reseña de un cliente que incluye el título de la reseña, la descripción en texto y una calificación (de 1 a 5) para un producto, entre otras características.
#
# Convertimos esto en un problema de clasificación binaria de la siguiente manera: si un cliente recomienda un producto (etiqueta 1), entonces la calificación es mayor a 3; de lo contrario, no recomienda el producto (etiqueta 0).
#
# Objetivo principal: Aprovechar los atributos del texto de la reseña para predecir la calificación de recomendación (clasificación).
#
# ![](https://storage.googleapis.com/kaggle-datasets-images/11827/16290/140ca3b71ec51512dcac444c57583f25/dataset-cover.jpg?t=2018-02-03-20-33-18)

# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/Womens_Clothing_E-Commerce_Reviews.csv', keep_default_na=False)
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33
# 1           1         1080   34
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...
